# %% [markdown]
# # 1.understanding the data

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv("zomato.csv")

# %%
df1.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# # EDA

# %%
df1.shape
# Out:
# (9551, 21)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df1.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %% [markdown]
# # checking null value

# %%
df1.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# #there is no any null value

# %%
#review descriptive data
df1.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# # Here we put the second data

# %%
df_country=pd.read_csv('country code.csv')

# %%
df_country
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df_country.shape
# Out:
# (15, 2)

# %% [markdown]
# # Here we can get final df with country name with the help of merge

# %%
df=pd.merge(df1,df_country, on='Country Code' , how='left')

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
#checking for the null values
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# Here is no any null value

# %%
#droping unwanted columns
df.drop(['Restaurant ID','Country Code','Locality Verbose','Longitude','Latitude'],axis=1,inplace=True)

# %%
df.head()
# Out:
#           Restaurant Name              City  \
# 0        Le Petit Souffle       Makati City
# 1        Izakaya Kikufuji       Makati City
# 2  Heat - Edsa Shangri-La  Mandaluyong City
# 3                    Ooma  Mandaluyong City
# 4             Sambo Kojin  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                            Cuisines  Average Cost for two          Currency  \
# ...

# %%
top_3=df['Country'].value_counts()[:3]
top_3
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Name: Country, dtype: int64

# %% [markdown]
# # pie chart

# %%
#plotting pie chart
plt.pie(top_3,labels=top_3.index)
#creating a circle
circle=plt.Circle((0,0),0.3, color='white')
#adding circle to the piechart
p=plt.gcf()
p.gca().add_artist(circle)
plt.title("Top 3 countries that uses zomato")
plt.show()

# %% [markdown]
# # Top 10 countries that uses zomato

# %%
Top_10=df['Country'].value_counts()[:10].rename_axis('Country').reset_index(name='count')
Top_10.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_b9b45_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b9b45_row1_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_b9b45_row2_col1, #T_b9b45_row3_col1, #T_b9b45_row4_col1, #T_b9b45_row5_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_b9b45_row6_col1, #T_b9b45_row7_col1, #T_b9b45_row8_col1, #T_b9b45_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_b9b45">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9b45_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_b9b45_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9b45_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9b45_row0_col0" class="data row0 col0" >India</td>
#       <td id="T_b9b45_row0_col1" class="data row0 col1" >8652</td>
# ...

# %% [markdown]
# # countries with minimum transactions

# %%
df['Country'].value_counts()[-3:].rename_axis('Country').reset_index(name='count').style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_4bdfe_row0_col1, #T_4bdfe_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_4bdfe_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_4bdfe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4bdfe_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_4bdfe_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4bdfe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4bdfe_row0_col0" class="data row0 col0" >Qatar</td>
#       <td id="T_4bdfe_row0_col1" class="data row0 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_4bdfe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4bdfe_row1_col0" class="data row1 col0" >Sri Lanka</td>
#       <td id="T_4bdfe_row1_col1" class="data row1 col1" >20</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# # MOST POPULAR Cuisines

# %%
popular_Cuisines=df['Cuisines'].value_counts()[:10].rename_axis('Cuisines').reset_index(name='count')
popular_Cuisines.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_ec301_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ec301_row1_col1 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_ec301_row2_col1, #T_ec301_row3_col1 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_ec301_row4_col1 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_ec301_row5_col1 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_ec301_row6_col1 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_ec301_row7_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_ec301_row8_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_ec301_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_ec301">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec301_level0_col0" class="col_heading level0 col0" >Cuisines</th>
# ...

# %% [markdown]
# # scatter plot

# %%
#add title
plt.title( "mostr popular Cuisines")
sns.scatterplot(y=popular_Cuisines['Cuisines'],x=popular_Cuisines['count'],hue=popular_Cuisines['Cuisines'])
# Out:
# <AxesSubplot:title={'center':'mostr popular Cuisines'}, xlabel='count', ylabel='Cuisines'>

# %% [markdown]
#  ↑↑↑↑ the top most popular Cuisines are North Indian and chinese

# %%
#Analysis 'has only delivery ' column

df['Has Online delivery'].value_counts()
# Out:
# No     7100
# Yes    2451
# Name: Has Online delivery, dtype: int64

# %% [markdown]
# # heatmap

# %%
plt.figure(figsize=(12,7))
ax=sns.heatmap(df.corr(),annot=True,linewidths=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Countplot

# %%
sns.countplot(x='Has Online delivery' , data=df,palette=['red','green'])
# Out:
# <AxesSubplot:xlabel='Has Online delivery', ylabel='count'>

# %%
# Which Countries do have online deliveries option
df[df['Has Online delivery']=='Yes'].Country.value_counts()
# Out:
# India    2423
# UAE        28
# Name: Country, dtype: int64

# %% [markdown]
# online delivery available only India and UAE

# %%
#Analysing 'Rating color' column


sns.countplot(x='Rating color',data=df,palette=['darkgreen','green','yellow','orange','grey','red'])
# Out:
# <AxesSubplot:xlabel='Rating color', ylabel='count'>

# %%
#Analysing 'Averagee Cost for two' column
by_rating=df.groupby(['Rating color']).mean().round()

# %%
by_rating
# Out:
#               Average Cost for two  Price range  Aggregate rating  Votes
# Rating color
# Dark Green                  8137.0          3.0               5.0  852.0
# Green                       3556.0          3.0               4.0  520.0
# Orange                       568.0          2.0               3.0   48.0
# Red                          638.0          2.0               2.0   91.0
# White                        340.0          1.0               0.0    1.0
# Yellow                      1045.0          2.0               4.0  229.0

# %% [markdown]
# # Barplot

# %%
plt.title("Aggregate rating vs Average Cost for two")     #Add title

sns.barplot(x=by_rating['Aggregate rating'],y=by_rating['Average Cost for two'])
# Out:
# <AxesSubplot:title={'center':'Aggregate rating vs Average Cost for two'}, xlabel='Aggregate rating', ylabel='Average Cost for two'>

# %% [markdown]
# Top rated restaurants have high average cost

# %%
#Analysing 'Rating text' column


plt.title("Aggregate rating vs Average Cost for two")     #Add title

sns.barplot(x=by_rating['Aggregate rating'],y=by_rating['Average Cost for two'],palette=['cyan','orange','red','green','blue','grey'])
# Out:
# <AxesSubplot:title={'center':'Aggregate rating vs Average Cost for two'}, xlabel='Aggregate rating', ylabel='Average Cost for two'>

# %%
plt.title("Rating text vs Average Cost for two")     #Add title
sns.barplot(x=df['Rating text'],y=df['Average Cost for two'],palette=['cyan','orange', 'red', 'green', 'blue','grey'])
# Out:
# <AxesSubplot:title={'center':'Rating text vs Average Cost for two'}, xlabel='Rating text', ylabel='Average Cost for two'>

# %% [markdown]
# # combining different features

# %%
# to create a table with selected features for better understanding


df.groupby(['Rating color','Aggregate rating','Rating text']).mean().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_79b7f_row0_col0, #T_79b7f_row12_col0, #T_79b7f_row16_col0 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_79b7f_row0_col1 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_79b7f_row0_col2 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_79b7f_row1_col0 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_79b7f_row1_col1, #T_79b7f_row4_col2 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_79b7f_row1_col2 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_79b7f_row2_col0, #T_79b7f_row10_col0, #T_79b7f_row11_col0, #T_79b7f_row14_col2, #T_79b7f_row17_col0, #T_79b7f_row18_col0, #T_79b7f_row24_col0, #T_79b7f_row25_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_79b7f_row2_col1 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_79b7f_row2_col2 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# ...

# %%
# Aggregate vs price range
plt.title("Aggregate rating vs Price range")     #Add title

sns.barplot(x=by_rating['Aggregate rating'],y=by_rating['Price range'],palette=['cyan','orange','red','green','blue','grey'])
# Out:
# <AxesSubplot:title={'center':'Aggregate rating vs Price range'}, xlabel='Aggregate rating', ylabel='Price range'>

# %%
plt.title("Aggregate rating vs Price  range")     #Add title

sns.barplot(x=by_rating['Aggregate rating'],y=by_rating['Price range'])
# Out:
# <AxesSubplot:title={'center':'Aggregate rating vs Price  range'}, xlabel='Aggregate rating', ylabel='Price range'>

# %% [markdown]
# # lets convert the boolean columns into integers

# %%
df = df[(df['Country']=='India')]
df.shape # (row,column)
# Out:
# (8652, 17)

# %%
df['Has Table booking'].replace({'Yes':1,'No':0},inplace=True)
df['Has Online delivery'].replace({'Yes':1,'No':0},inplace=True)
df['Switch to order menu'].replace({'Yes':1,'No':0},inplace=True)

# %%
df.head()
# Out:
#                            Restaurant Name  City  \
# 624                             Jahanpanah  Agra
# 625                    Rangrezz Restaurant  Agra
# 626                Time2Eat - Mama Chicken  Agra
# 627  Chokho Jeeman Marwari Jain Bhojanalya  Agra
# 628                         Pinch Of Spice  Agra
#
#                                                Address     Locality  \
# 624  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 625  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 626        Main Market, Sadar Bazaar, Agra Cantt, Agra   Agra Cantt
# 627  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...  Civil Lines
# 628  23/453, Opposite Sanjay Cinema, Wazipura Road,...  Civil Lines
#
#                            Cuisines  Average Cost for two            Currency  \
# 624           North Indian, Mughlai                   850  Indian Rupees(Rs.)
# 625           North Indian, Mughlai                   700  Indian Rupees(Rs.)
# ...

# %%
#The average cost of two can be dependent on the cuisin of thr restaurant
#continental and italian will be more costly tha northindian:)
#leta find out the number of unique cuisins
cuisines= list(set(df['Cuisines'].str.cat(sep=',').replace(" ","").split(',')))
cuisines.sort()
cuisines
# Out:
# ['Afghani',
#  'African',
#  'American',
#  'Andhra',
#  'Arabian',
#  'Armenian',
#  'Asian',
#  'Assamese',
#  'Awadhi',
#  'BBQ',
#  'Bakery',
#  'Belgian',
#  'Bengali',
#  'Beverages',
#  'Bihari',
#  'Biryani',
#  'British',
#  'Burger',
#  'Burmese',
#  'Cafe',
#  'Cajun',
#  'CharcoalGrill',
#  'Chettinad',
#  'Chinese',
#  'Continental',
#  'CuisineVaries',
#  'Deli',
#  'Desserts',
#  'DrinksOnly',
#  'European',
#  'FastFood',
#  'FingerFood',
#  'French',
#  'German',
#  'Goan',
#  'Greek',
#  'Gujarati',
#  'HealthyFood',
#  'Hyderabadi',
#  'IceCream',
#  'Indian',
#  'Indonesian',
#  'Iranian',
#  'Italian',
#  'Japanese',
#  'Juices',
#  'Kashmiri',
#  'Kerala',
#  'Korean',
#  'Lebanese',
#  'Lucknowi',
#  'Maharashtrian',
#  'Malaysian',
#  'Malwani',
#  'Mangalorean',
#  'Mediterranean',
#  'Mexican',
#  'MiddleEastern',
#  'Mithai',
#  'ModernIndian',
#  'Moroccan',
#  'Mughlai',
#  'Naga',
#  'Nepalese',
#  'NorthEastern',
#  'NorthIndian',
#  'Oriya',
# ...

# %%
# Add one column for each cuisine and set value 1 for the column if restaurant 
# serves that cuisine else 0 
# Ultimately ,we are doing conversion of categorical columns into numerical columns.
for Cuisine in cuisines :
    df[Cuisine]=df['Cuisines'].str.contains(Cuisine)
    df[Cuisine].replace({'True': 1,'False':0}, inplace=True)
df.head()
# Out:
#                            Restaurant Name  City  \
# 624                             Jahanpanah  Agra
# 625                    Rangrezz Restaurant  Agra
# 626                Time2Eat - Mama Chicken  Agra
# 627  Chokho Jeeman Marwari Jain Bhojanalya  Agra
# 628                         Pinch Of Spice  Agra
#
#                                                Address     Locality  \
# 624  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 625  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 626        Main Market, Sadar Bazaar, Agra Cantt, Agra   Agra Cantt
# 627  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...  Civil Lines
# 628  23/453, Opposite Sanjay Cinema, Wazipura Road,...  Civil Lines
#
#                            Cuisines  Average Cost for two            Currency  \
# 624           North Indian, Mughlai                   850  Indian Rupees(Rs.)
# 625           North Indian, Mughlai                   700  Indian Rupees(Rs.)
# ...

# %%
# Let's find out how each column is linearly related with Cost for two
corr=df.corr()[['Average Cost for two']].sort_values('Average Cost for two',ascending=False)
corr[corr['Average Cost for two']>0.2]
# Out:
#                       Average Cost for two
# Average Cost for two              1.000000
# Price range                       0.837964
# Has Table booking                 0.609883
# Aggregate rating                  0.344172
# Continental                       0.328463
# Votes                             0.281765
# Italian                           0.277967
# European                          0.259520
# Asian                             0.206841

# %%
#we are going to pick the top 5 featuring for building our regression on model
df=df[['Price range','Has Table booking','Aggregate rating','Continental','Votes','Average Cost for two']]

# %%
df.head()
# Out:
#      Price range  Has Table booking  Aggregate rating  Continental  Votes  \
# 624            3                  0               3.9        False    140
# 625            2                  0               3.5        False     71
# 626            2                  0               3.6        False     94
# 627            2                  0               4.0        False     87
# 628            3                  0               4.2        False    177
#
#      Average Cost for two
# 624                   850
# 625                   700
# 626                   500
# 627                   400
# 628                  1000

# %% [markdown]
# # lets use MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(df)
df=pd.DataFrame(scaler.transform(df),columns=df.columns)
df.head()
# Out:
#    Price range  Has Table booking  Aggregate rating  Continental     Votes  \
# 0     0.666667                0.0          0.795918          0.0  0.012804
# 1     0.333333                0.0          0.714286          0.0  0.006494
# 2     0.333333                0.0          0.734694          0.0  0.008597
# 3     0.333333                0.0          0.816327          0.0  0.007957
# 4     0.666667                0.0          0.857143          0.0  0.016188
#
#    Average Cost for two
# 0               0.10625
# 1               0.08750
# 2               0.06250
# 3               0.05000
# 4               0.12500

# %% [markdown]
# # Split data into train_test_spllit

# %%
# split data into training and testing set
from sklearn.model_selection import train_test_split

train,test = train_test_split(df,random_state=50)
x_train = train.iloc[:,df.columns!='Average Cost for two']
x_test = test.iloc[:,df.columns!='Average Cost for two']
y_train = train['Average Cost for two']
y_test = test['Average Cost for two']
print('Training set size - ' , x_train.shape)
print('Testing set size - ' , x_test.shape)
# Out:
# Training set size -  (6489, 5)
# Testing set size -  (2163, 5)

# %% [markdown]
# # LinearRegression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

reg=LinearRegression()
reg.fit(x_train,y_train)
y_pred=reg.predict(x_test)
score=r2_score(y_test,y_pred)
score
# Out:
# 0.7021408105248419

# %% [markdown]
# As we can see that LinearRegression gives us r2_score of 0.7 but we should try to find out if any other model can give us better results. Let's try to build a model using Polynomial Regression. To help us find the best degree of fit for polynomial regression, we will be using validation curve.

# %% [markdown]
# # Function to plot validation curve

# %%
from sklearn.model_selection import validation_curve
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt

def plot_validation_curve(model,param_name,x_label,param_range=np.arange(1,7)):
    train_scores,validation_scores = validation_curve(model,x_train, y_train,param_name = param_name,param_range=param_range,scoring='r2',cv=3)
    validation_scores[validation_scores < 0] = 0 
    print('Training scores  ',train_scores.mean(axis=1))
    print('Validation scores  ',validation_scores.mean(axis=1))
    
    plt.figure(figsize=(6, 4))
    plt.plot(param_range,validation_scores.mean(axis=1),lw=2, label='validation')
    plt.plot(param_range,train_scores.mean(axis=1),lw=2, label='training')
    plt.xlabel(x_label)
    plt.ylabel('Score')
    plt.title('Validation curve')
    plt.legend(loc='best')
    plt.show()

# %%
model=make_pipeline(PolynomialFeatures(),LinearRegression())
plot_validation_curve(model,'polynomialfeatures__degree', x_label='Degree of polynomial')
# Out:
# Training scores   [0.73491071 0.81073298 0.82599195 0.83583253 0.84672401 0.85860956]
# Validation scores   [0.73473614 0.80764631 0.81088033 0.26193655 0.23858198 0.        ]

# %% [markdown]
# Both the training and cross validation scores increase till 3rd degree of polynomial after which the cross validation score starts to decrease while the training score keeps increasing i.e our model starts to overfit for higher degree of polynomial. So, our best pick for polynomial degree is 3. Let's build the model and test it on our test data!

# %%
polynomial_features=PolynomialFeatures(degree=3)
x_train_poly=polynomial_features.fit_transform(x_train)
x_test_poly=polynomial_features.fit_transform(x_test)
reg= LinearRegression()
reg.fit(x_train_poly,y_train)
y_pred=reg.predict(x_test_poly)
score=r2_score(y_test,y_pred)
score
# Out:
# 0.8236498480244454

# %% [markdown]
# # DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
plot_validation_curve(DecisionTreeRegressor(random_state=42),'max_depth','Max Depth')
# Out:
# Training scores   [0.57380658 0.79647433 0.81377013 0.8277436  0.84064222 0.86190205]
# Validation scores   [0.57462647 0.79580607 0.81280331 0.81308201 0.80395442 0.79772311]

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
plot_validation_curve(RandomForestRegressor(random_state=50,n_estimators=10),'max_depth','Max Depth',np.arange(1,10))
# Out:
# Training scores   [0.57356635 0.79638538 0.81476401 0.83297485 0.84936714 0.86634223
#  0.88513181 0.89863597 0.91254187]
# Validation scores   [0.57463042 0.79567118 0.81342838 0.81913066 0.81761562 0.8088364
#  0.80372428 0.79594413 0.7854252 ]

# %% [markdown]
# # CONCLUSION
# Here, I have come to the end of this project on the topic { zomato restaurant prediction} I would like to share my experience which doing this project, I leran many new things about the machine learning and it was wonderfull learning and experience for me while working on this project This projecct increse my research thinkin skill and intrestinng in ml project
#
# A very special thanks to my project sir for setting such a helpfull target for us..
#
# thank you..🤗🤗🤗🤗
